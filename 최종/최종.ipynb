# %%
# !git clone https://github.com/Jang-jiwon/CowDetect.git
# %cd CowDetect
# !git submodule update --init --recursive
# Out:
# Cloning into 'CowDetect'...
# remote: Enumerating objects: 31552, done.
# remote: Counting objects: 100% (11499/11499), done.
# remote: Compressing objects: 100% (10168/10168), done.
# remote: Total 31552 (delta 604), reused 11430 (delta 571), pack-reused 20053
# Receiving objects: 100% (31552/31552), 954.22 MiB | 30.13 MiB/s, done.
# Resolving deltas: 100% (605/605), done.
# Checking out files: 100% (6499/6499), done.
# /content/CowDetect
# Submodule 'StrongSORT-YOLO' (https://github.com/bharath5673/StrongSORT-YOLO.git) registered for path 'StrongSORT-YOLO'
# Cloning into '/content/CowDetect/StrongSORT-YOLO'...
# Submodule path 'StrongSORT-YOLO': checked out '187aea4f482e1b1f396cd97f31cd51c33cc82b05'
# Submodule 'yolov5' (https://github.com/ultralytics/yolov5.git) registered for path 'StrongSORT-YOLO/yolov5'
# Submodule 'yolov7' (https://github.com/WongKinYiu/yolov7.git) registered for path 'StrongSORT-YOLO/yolov7'
# Cloning into '/content/CowDetect/StrongSORT-YOLO/yolov5'...
# ...

# %%
# !git clone --recurse-submodules https://github.com/bharath5673/StrongSORT-YOLO.git
# Out:
# fatal: destination path 'StrongSORT-YOLO' already exists and is not an empty directory.

# %%
# %cd /content/StrongSORT-YOLO
# Out:
# [Errno 2] No such file or directory: '/content/StrongSORT-YOLO'
# /content/CowDetect

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
#https://drive.google.com/file/d/1erzrvvkTs1Q4omWKQauzJC90VyK7f3VG/view?usp=sharing
# !wget --load-cookies ~/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies ~/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1erzrvvkTs1Q4omWKQauzJC90VyK7f3VG' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1erzrvvkTs1Q4omWKQauzJC90VyK7f3VG" -O sample_video.mp4 && rm -rf ~/cookies.txt
# Out:
# --2022-10-13 14:26:07--  https://docs.google.com/uc?export=download&confirm=&id=1erzrvvkTs1Q4omWKQauzJC90VyK7f3VG
# Resolving docs.google.com (docs.google.com)... 172.217.203.101, 172.217.203.139, 172.217.203.100, ...
# Connecting to docs.google.com (docs.google.com)|172.217.203.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-04-0o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/dv38aribh1e9838244te7vban8gkrtlv/1665671100000/09616441021195754918/*/1erzrvvkTs1Q4omWKQauzJC90VyK7f3VG?e=download&uuid=6b6057c0-db8f-42b7-91ea-e8b3f4198fe8 [following]
# ...
# --2022-10-13 14:26:08--  https://doc-04-0o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/dv38aribh1e9838244te7vban8gkrtlv/1665671100000/09616441021195754918/*/1erzrvvkTs1Q4omWKQauzJC90VyK7f3VG?e=download&uuid=6b6057c0-db8f-42b7-91ea-e8b3f4198fe8
# ...

# %%
# %cd /content/StrongSORT-YOLO
# Out:
# /content/StrongSORT-YOLO

# %%
# !python track_v5.py --source /content/StrongSORT-YOLO/sample_video.mp4 --img 640 --save-vid
# Out:
# track_v5: yolo_weights=/content/StrongSORT-YOLO/weights/yolov5n.pt, strong_sort_weights=/content/StrongSORT-YOLO/weights/osnet_x0_25_msmt17.pt, config_strongsort=strong_sort/configs/strong_sort.yaml, source=/content/StrongSORT-YOLO/sample_video.mp4, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.5, max_det=1000, device=, show_vid=False, save_txt=False, save_conf=False, save_crop=False, save_vid=True, nosave=False, count=False, draw=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/track, name=exp, exist_ok=False, line_thickness=2, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False
# YOLOv5 🚀 2022-10-13 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients
# Model: osnet_x0_25
# - params: 203,568
# - flops: 82,316,000
# Successfully loaded pretrained weights from "/content/StrongSORT-YOLO/weights/osnet_x0_25_msmt17.pt"
# ...

# %%
# !python track_v5.py --source test.mp4 -yolo-weights /content/StrongSORT-YOLO/weights/yolov5m.pt --save-txt --count --show-vid --draw
# Out:
# usage: track_v5.py [-h] [--yolo-weights YOLO_WEIGHTS [YOLO_WEIGHTS ...]]
#                    [--strong-sort-weights STRONG_SORT_WEIGHTS]
#                    [--config-strongsort CONFIG_STRONGSORT] [--source SOURCE]
#                    [--imgsz IMGSZ [IMGSZ ...]] [--conf-thres CONF_THRES]
#                    [--iou-thres IOU_THRES] [--max-det MAX_DET]
#                    [--device DEVICE] [--show-vid] [--save-txt] [--save-conf]
#                    [--save-crop] [--save-vid] [--nosave] [--count] [--draw]
#                    [--classes CLASSES [CLASSES ...]] [--agnostic-nms]
#                    [--augment] [--visualize] [--update] [--project PROJECT]
#                    [--name NAME] [--exist-ok]
#                    [--line-thickness LINE_THICKNESS] [--hide-labels]
#                    [--hide-conf] [--hide-class] [--half] [--dnn]
# track_v5.py: error: unrecognized arguments: -yolo-weights /content/StrongSORT-YOLO/weights/yolov5m.pt

# %%
python track_v5.py --source 0 --yolo-weights /content/StrongSORT-YOLO/weights/yolov5m.pt --classes 19  # tracks persons, only
# Out:
#   File "<ipython-input-8-443f2a60cf37>", line 1
#     python track_v5.py --source 0 --yolo-weights /content/StrongSORT-YOLO/weights/yolov5m.pt --classes 19  # tracks persons, only
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##활동량 기록

# %%
import json
import pandas as pd

with open("/content/activity_volume.json", 'r') as f :
  json_data = json.load(f)

json_data

# %%
import json
import pandas as pd

with open("/content/activity_dic.json", 'r') as f :
  json_data_2 = json.load(f)

json_data_2

# %%
import json
import pandas as pd

with open("/content/activity_max.json", 'r') as f :
  json_data_2 = json.load(f)

json_data_2

# %%
import json
import pandas as pd

with open("/content/activity_mean.json", 'r') as f :
  json_data_2 = json.load(f)

json_data_2

# %%
# print(json_data_2['6.0'])
x = []
y = []
for i in json_data_2 :
  print(i,':', json_data_2[i])
  x.append(i)
  y.append(json_data_2[i])

# print(x)
# print(y)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(30,5))
plt.plot(x, y)
plt.xlabel('time')
plt.ylabel('activity')
plt.title('6초당 누적 활동량')
plt.rc('font', family='NanumBarunGothic') 
plt.show()
