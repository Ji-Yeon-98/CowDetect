# %%
# !git clone https://github.com/youtube-jocoding/python-crawling.git
# Out:
# Cloning into 'python-crawling'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 8 (delta 1), reused 6 (delta 0), pack-reused 0
# Unpacking objects: 100% (8/8), done.

# %%
# !pip install git+https://github.com/Joeclinton1/google-images-download.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/Joeclinton1/google-images-download.git to /tmp/pip-req-build-irgf4ea1
#   Running command git clone -q https://github.com/Joeclinton1/google-images-download.git /tmp/pip-req-build-irgf4ea1
# ...
#      |████████████████████████████████| 985 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 358 kB 48.5 MB/s
# ...
#      |████████████████████████████████| 140 kB 54.1 MB/s
# ...
#      |████████████████████████████████| 58 kB 5.1 MB/s
# ...
#   Created wheel for google-images-download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=16150 sha256=ad7c663da1ad422fd5996b9c562202ca7932f7558e7ea0276e38ee23b02af4dc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zn4n388l/wheels/79/5c/d2/2569a4f55ff29b3c4d6b1114d5110a70a79afbf381e6eb3e87
# Successfully built google-images-download
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
# ...

# %%
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"초원","limit":100,"print_urls":True, "format": "jpg"}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print("/content/hi")   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = \ucd08\uc6d0
# Evaluating...
# Starting Download...
# Image URL: http://kr.xinhuanet.com/2021-06/08/139993900_16231136055131n.jpg
# Completed Image ====> 1.139993900_16231136055131n.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/thumb/4/46/Grasslands-menggu.JPG/240px-Grasslands-menggu.JPG
# Completed Image ====> 2.240px-grasslands-menggu.jpg
# Image URL: https://images.freeimages.com/images/large-previews/3f3/meadow-1347877.jpg
# Completed Image ====> 3.meadow-1347877.jpg
# Image URL: https://image.utoimage.com/preview/cp872655/2017/08/201708004472_500.jpg
# Completed Image ====> 4.201708004472_500.jpg
# Image URL: https://pds.joongang.co.kr/news/component/htmlphoto_mmdata/201607/01/htm_2016070117358644661.jpg
# Completed Image ====> 5.htm_2016070117358644661.jpg
# Image URL: https://t1.daumcdn.net/tistoryfile/fs12/34_tistory_2008_12_13_23_07_4943c1b14510c?original
# Completed Image ====> 6.34_tistory_2008_12_13_23_07_4943c1b14510c.jpg
# ...

# %%
import shutil
import zipfile
import os

os.chdir('/content')
os.getcwd()

shutil.make_archive('cow1', 'zip', '/content/downloads/field ')
# Out:
# '/content/cow1.zip'
